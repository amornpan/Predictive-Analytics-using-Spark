# %%
sc
# Out:
# <SparkContext master=yarn appName=PySparkShell>

# %%
! wget https://storage.googleapis.com/grizzy-lab/LoanStats_web.csv
# Out:
# --2022-06-29 06:24:47--  https://storage.googleapis.com/grizzy-lab/LoanStats_web.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 142.250.99.128, 173.194.202.128, 74.125.20.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|142.250.99.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1160243241 (1.1G) [text/csv]
# Saving to: ‘LoanStats_web.csv’
#
# LoanStats_web.csv   100%[===================>]   1.08G   129MB/s    in 6.7s
#
# 2022-06-29 06:24:54 (165 MB/s) - ‘LoanStats_web.csv’ saved [1160243241/1160243241]

# %%
! ls -lh LoanStats_web.csv
# Out:
# -rw-r--r-- 1 root root 1.1G Aug 14  2021 LoanStats_web.csv

# %%
! head -5 LoanStats_web.csv
# Out:
# "id","member_id","loan_amnt","funded_amnt","funded_amnt_inv","term","int_rate","installment","grade","sub_grade","emp_title","emp_length","home_ownership","annual_inc","verification_status","issue_d","loan_status","pymnt_plan","url","desc","purpose","title","zip_code","addr_state","dti","delinq_2yrs","earliest_cr_line","inq_last_6mths","mths_since_last_delinq","mths_since_last_record","open_acc","pub_rec","revol_bal","revol_util","total_acc","initial_list_status","out_prncp","out_prncp_inv","total_pymnt","total_pymnt_inv","total_rec_prncp","total_rec_int","total_rec_late_fee","recoveries","collection_recovery_fee","last_pymnt_d","last_pymnt_amnt","next_pymnt_d","last_credit_pull_d","collections_12_mths_ex_med","mths_since_last_major_derog","policy_code","application_type","annual_inc_joint","dti_joint","verification_status_joint","acc_now_delinq","tot_coll_amt","tot_cur_bal","open_acc_6m","open_act_il","open_il_12m","open_il_24m","mths_since_rcnt_il","total_bal_il","il_util","open_rv_12m","open_rv_24m","max_bal_bc","all_util","total_rev_hi_lim","inq_fi","total_cu_tl","inq_last_12m","acc_open_past_24mths","avg_cur_bal","bc_open_to_buy","bc_util","chargeoff_within_12_mths","delinq_amnt","mo_sin_old_il_acct","mo_sin_old_rev_tl_op","mo_sin_rcnt_rev_tl_op","mo_sin_rcnt_tl","mort_acc","mths_since_recent_bc","mths_since_recent_bc_dlq","mths_since_recent_inq","mths_since_recent_revol_delinq","num_accts_ever_120_pd","num_actv_bc_tl","num_actv_rev_tl","num_bc_sats","num_bc_tl","num_il_tl","num_op_rev_tl","num_rev_accts","num_rev_tl_bal_gt_0","num_sats","num_tl_120dpd_2m","num_tl_30dpd","num_tl_90g_dpd_24m","num_tl_op_past_12m","pct_tl_nvr_dlq","percent_bc_gt_75","pub_rec_bankruptcies","tax_liens","tot_hi_cred_lim","total_bal_ex_mort","total_bc_limit","total_il_high_credit_limit","revol_bal_joint","sec_app_earliest_cr_line","sec_app_inq_last_6mths","sec_app_mort_acc","sec_app_open_acc","sec_app_revol_util","sec_app_open_act_il","sec_app_num_rev_accts","sec_app_chargeoff_within_12_mths","sec_app_collections_12_mths_ex_med","sec_app_mths_since_last_major_derog","hardship_flag","hardship_type","hardship_reason","hardship_status","deferral_term","hardship_amount","hardship_start_date","hardship_end_date","payment_plan_start_date","hardship_length","hardship_dpd","hardship_loan_status","orig_projected_additional_accrued_interest","hardship_payoff_balance_amount","hardship_last_payment_amount","debt_settlement_flag","debt_settlement_flag_date","settlement_status","settlement_date","settlement_amount","settlement_percentage","settlement_term"
# "","","30000","30000","30000"," 36 months","  9.75%","964.5","B","B3","","n/a","MORTGAGE","89600","Verified","Mar-2016","Fully Paid","n","","","debt_consolidation","Debt consolidation","233xx","VA","21.15","0","Oct-1996","1","51","","22","0","45643","64%","43","w","0.00","0.00","34683.4671902942","34683.47","30000.00","4683.47","0.0","0.0","0.0","Feb-2019","1922.97","","Oct-2019","0","","1","Individual","","","","0","0","45643","0","0","0","0","64","0","0","2","4","4412","64","71690","0","3","1","4","2282","3586","44","0","0","165","233","7","7","1","16","","2","51","0","7","20","12","12","7","20","35","17","20","","0","0","2","98","57.1","0","0","71690","45643","25100","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","25000","25000","25000"," 36 months","  5.32%","752.87","A","A1","Carman welder","10+ years","MORTGAGE","70000","Not Verified","Mar-2016","Fully Paid","n","","","debt_consolidation","Debt consolidation","758xx","TX","21.81","0","Jul-1983","0","","","16","0","4091","6.8%","54","w","0.00","0.00","27088.521784058","27088.52","25000.00","2088.52","0.0","0.0","0.0","Apr-2019","752.85","","Mar-2019","0","","1","Individual","","","","0","0","51894","0","5","0","4","13","47803","79","0","1","1306","43","60000","2","24","1","5","3460","32694","3.8","0","0","155","392","20","13","1","29","","9","","0","1","2","6","13","31","11","22","2","16","0","0","0","0","100","0","0","0","120454","51894","34000","60454","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","6950","6950","6950"," 36 months","  7.39%","215.84","A","A4","Reverse Mortgage Specialist","2 years","OWN","50000","Source Verified","Mar-2016","Fully Paid","n","","","home_improvement","","331xx","FL","5.66","0","May-1995","0","55","53","5","4","7096","59.1%","26","w","0.00","0.00","7280.3477070502","7280.35","6950.00","330.35","0.0","0.0","0.0","Dec-2016","5775.18","","Oct-2018","0","55","1","Individual","","","","0","0","7096","0","0","0","0","91","0","","0","1","5255","59","12000","0","0","1","1","1419","2934","69.8","0","0","153","205","17","17","8","31","","11","55","1","3","4","3","7","3","5","15","4","5","0","0","0","0","91.3","33.3","3","1","12000","7096","9700","0","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""
# "","","28000","28000","28000"," 36 months"," 11.47%","922.93","B","B5","general manager","10+ years","MORTGAGE","75000","Not Verified","Mar-2016","Charged Off","n","","","debt_consolidation","","229xx","VA","16.9","2","Aug-2001","1","1","","10","0","27989","47.8%","29","w","0.00","0.00","24356.77","24356.77","18406.72","4630.85","0.0","1319.2","237.456","May-2018","922.93","","Oct-2018","0","50","1","Individual","","","","0","0","364105","0","1","0","1","16","29852","","0","0","16786","47","58500","1","0","3","2","36411","30511","47.8","0","0","154","151","30","16","5","30","1","0","1","1","3","3","7","11","8","7","14","3","10","0","0","0","0","86.2","14.3","0","0","405763","58019","58500","35854","","","","","","","","","","","","N","","","","","","","","","","","","","","","N","","","","","",""

# %%
# !wc -l LoanStats_web.csv
# Out:
# 1432493 LoanStats_web.csv

# %%
! hdfs dfs -rm /user/root/LoanStats_web.csv
# Out:
# rm: `/user/root/LoanStats_web.csv': No such file or directory

# %%
! pwd
# Out:
# /

# %%
! hdfs dfs -put LoanStats_web.csv /user/root

# %%
! hdfs dfs -ls /user/root/
# Out:
# Found 2 items
# drwxr-xr-x   - root hadoop          0 2022-06-29 06:24 /user/root/.sparkStaging
# -rw-r--r--   2 root hadoop 1160243241 2022-06-29 06:25 /user/root/LoanStats_web.csv

# %%
raw_df = spark.read.format('csv').\
option('header','true').option('mode','DROPMALFORMED').load('/user/root/LoanStats_web.csv')

# %%
len(raw_df.columns)
# Out:
# 144

# %%
raw_df.count()
# Out:
# 1432466

# %%
selecteAttr_df = raw_df.select(
 'loan_amnt',
 'term',
 'int_rate',
 'installment',
 'grade',
 'emp_length',
 'home_ownership',
 'annual_inc',
 'verification_status',
 'loan_status',
 'purpose',
 'addr_state',
 'dti',
 'delinq_2yrs',
 'earliest_cr_line',
 'inq_last_6mths',
 'open_acc',
 'pub_rec',
 'revol_bal',
 'revol_util',
 'total_acc',
 'last_credit_pull_d')

# %%
len(selecteAttr_df.columns)
# Out:
# 22

# %%
! pip install pandas
# Out:
# Requirement already satisfied: pandas in /opt/conda/anaconda/lib/python3.7/site-packages (1.2.5)
# Requirement already satisfied: numpy>=1.16.5 in /opt/conda/anaconda/lib/python3.7/site-packages (from pandas) (1.17.2)
# Requirement already satisfied: pytz>=2017.3 in /opt/conda/anaconda/lib/python3.7/site-packages (from pandas) (2019.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/anaconda/lib/python3.7/site-packages (from pandas) (2.8.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/anaconda/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
selecteAttr_df.describe().toPandas().transpose()
# Out:
#                            0                    1                   2  \
# summary                count                 mean              stddev
# loan_amnt            1432440   15370.388358325654   9646.026272413876
# term                 1432440                 None                None
# int_rate             1432440                 None                None
# installment          1432440   456.68781535698236  281.71344223131814
# grade                1432440                 None                None
# emp_length           1432440                 None                None
# home_ownership       1432440                 None                None
# annual_inc           1432440     81034.5829329675  134183.35696714348
# verification_status  1432440                 None                None
# loan_status          1432440                 None                None
# purpose              1432440                 None                None
# addr_state           1432440                 None                None
# dti                  1430856    19.21187297804439   15.97277532300163
# delinq_2yrs          1432440  0.30147182532729144  0.8643187650693964
# earliest_cr_line     1432440                 None                None
# inq_last_6mths       1432439   0.4954669902173845  0.7923339930576606
# open_acc             1432440   11.710318756806569   5.841056149724105
# pub_rec              1432439  0.20539234131435963  0.5861093697871795
# revol_bal            1432439   16846.678102173984  23301.014583199452
# revol_util           1431251                 19.0                 NaN
# total_acc            1432440   23.602901343162717  12.040983315039249
# last_credit_pull_d   1432416                 None                None
#
#                                                                      3  \
# summary                                                            min
# loan_amnt                                                         1000
# term                                                         36 months
# int_rate                                                         5.31%
# installment                                                     100.01
# grade                                                                A
# emp_length                                                      1 year
# home_ownership                                                     ANY
# annual_inc                                                           0
# verification_status                                       Not Verified
# loan_status                                                Charged Off
# purpose               and also pay off some credit card debt.  I wi...
# addr_state                                                          AK
# dti                                                                 -1
# delinq_2yrs                                                          0
# earliest_cr_line                                              Apr-1955
# inq_last_6mths                                                       0
# open_acc                                                             0
# pub_rec                                                              0
# revol_bal                                                            0
# revol_util                                                          0%
# total_acc                                                            0
# last_credit_pull_d                                            Apr-2016
#
#                                       4
# summary                             max
# loan_amnt                          9975
# term                          60 months
# int_rate                         30.99%
# installment                      999.98
# grade                                 G
# emp_length                          n/a
# home_ownership                     RENT
# annual_inc                     99999.84
# verification_status            Verified
# loan_status          Late (31-120 days)
# purpose                         wedding
# addr_state           debt_consolidation
# dti                  Debt consolidation
# delinq_2yrs                           9
# earliest_cr_line               Sep-2015
# inq_last_6mths                        5
# open_acc                             97
# pub_rec                               9
# revol_bal                         99996
# revol_util                        99.9%
# total_acc                            99
# last_credit_pull_d             Sep-2019

# %% [markdown]
# # Hands-On: Data Preparation (LAB II)
#
# ## Null, Data Type, Noise (%,-) and Normalization

# %%
noMissing_df = selecteAttr_df.dropna(how='any')

# %%
noMissing_df.count()
# Out:
# 1429645

# %%
raw_df.count() - noMissing_df.count()
# Out:
# 2821

# %%
noMissing_df.printSchema()
# Out:
# root
#  |-- loan_amnt: string (nullable = true)
#  |-- term: string (nullable = true)
#  |-- int_rate: string (nullable = true)
#  |-- installment: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- emp_length: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: string (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- loan_status: string (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- dti: string (nullable = true)
#  |-- delinq_2yrs: string (nullable = true)
#  |-- earliest_cr_line: string (nullable = true)
#  |-- inq_last_6mths: string (nullable = true)
#  |-- open_acc: string (nullable = true)
#  |-- pub_rec: string (nullable = true)
#  |-- revol_bal: string (nullable = true)
#  |-- revol_util: string (nullable = true)
#  |-- total_acc: string (nullable = true)
#  |-- last_credit_pull_d: string (nullable = true)

# %%
fitmem_noMissing_df = noMissing_df.repartition(60)

# %%
cached_noMissing_df = fitmem_noMissing_df.cache()

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import *

# %%
def f_removepercentsign(origin):
    return origin.rstrip('%')

# %%
removepercentsign = udf(lambda x: f_removepercentsign(x),StringType())

# %%
def f_extractmonth(origin):
    return origin.split('-')[0]

# %%
extractmonth = udf(lambda x: f_extractmonth(x),StringType())

# %%
crunched_df = cached_noMissing_df.\
withColumn('revol_util',removepercentsign(col('revol_util')).\
           cast(DoubleType())).\
withColumn('int_rate',removepercentsign(col('int_rate')).\
           cast(DoubleType())).\
withColumn('earliest_cr_line',extractmonth(col('earliest_cr_line')).\
           cast(StringType())).\
withColumn('last_credit_pull_d',extractmonth(col('last_credit_pull_d')).\
           cast(StringType())).\
withColumn('dti',col('dti').cast(DoubleType())).\
withColumn('loan_amnt',col('loan_amnt').cast(DoubleType())).\
withColumn('annual_inc',col('annual_inc').cast(DoubleType()))

# %%
crunched_df.groupBy(['revol_util','int_rate','earliest_cr_line','last_credit_pull_d']).count().show()
# Out:
# +----------+--------+----------------+------------------+-----+
# |revol_util|int_rate|earliest_cr_line|last_credit_pull_d|count|
# +----------+--------+----------------+------------------+-----+
# |      18.5|    6.08|             Jun|               Oct|    2|
# |      27.1|    7.46|             Apr|               Oct|    1|
# |      41.4|    6.72|             Jun|               Apr|    1|
# |      18.7|   17.47|             Feb|               Oct|    1|
# |      20.2|    7.35|             Aug|               Apr|    1|
# |      61.0|   12.74|             Dec|               Oct|   10|
# |      10.4|    7.49|             May|               Apr|    4|
# |      75.7|   28.69|             Mar|               Oct|    4|
# |      38.5|    8.24|             Sep|               Nov|    4|
# |      20.8|   14.99|             Jun|               Jun|    4|
# |      45.0|    7.89|             Nov|               Aug|    1|
# |       3.4|   10.75|             Aug|               Sep|    1|
# |      32.1|    6.97|             Oct|               Feb|    1|
# |      22.1|    9.75|             Aug|               Mar|    1|
# |      95.0|   11.47|             Jun|               Oct|    1|
# |      40.5|   12.99|             Apr|               Mar|    1|
# |      55.9|   11.99|             Jul|               Dec|    1|
# |      47.5|   13.44|             Jul|               Jan|    1|
# |      34.0|   22.39|             Dec|               Dec|    1|
# |      54.9|   14.46|             Nov|               Apr|    1|
# +----------+--------+----------------+------------------+-----+
# only showing top 20 rows

# %%
crunched_df = cached_noMissing_df.\
withColumn('revol_util',removepercentsign(cached_noMissing_df['revol_util'])\
           .cast(DoubleType())).\
withColumn('int_rate',removepercentsign(cached_noMissing_df['int_rate'])\
           .cast(DoubleType())).\
withColumn('earliest_cr_line',extractmonth(cached_noMissing_df['earliest_cr_line'])\
           .cast(StringType())).\
withColumn('last_credit_pull_d',extractmonth(cached_noMissing_df['last_credit_pull_d'])\
           .cast(StringType())).\
withColumn('dti',cached_noMissing_df['dti'].cast(DoubleType())).\
withColumn('loan_amnt',cached_noMissing_df['loan_amnt'].cast(DoubleType())).\
withColumn('annual_inc',cached_noMissing_df['annual_inc'].cast(DoubleType()))

# %%
crunched_df.groupBy(['revol_util','int_rate'\
                     ,'earliest_cr_line','last_credit_pull_d']).count().show()
# Out:
# +----------+--------+----------------+------------------+-----+
# |revol_util|int_rate|earliest_cr_line|last_credit_pull_d|count|
# +----------+--------+----------------+------------------+-----+
# |      61.0|   12.74|             Dec|               Oct|   10|
# |      75.0|   18.99|             Aug|               Apr|    4|
# |      66.1|   11.39|             Nov|               Mar|    4|
# |      60.3|    8.24|             May|               Jul|    4|
# |      61.5|   11.39|             Dec|               Aug|    1|
# |      38.1|   18.99|             Nov|               Sep|    1|
# |      60.2|    11.8|             Sep|               Oct|    1|
# |      27.0|   10.33|             Dec|               Oct|    5|
# |      28.4|   10.33|             Apr|               Oct|    2|
# |      87.4|   13.59|             Nov|               Oct|    1|
# |      14.5|   19.03|             Apr|               Sep|    1|
# |      21.5|    6.19|             Jun|               Oct|    1|
# |      58.1|   18.45|             Feb|               Oct|    1|
# |      44.6|   15.05|             Aug|               Apr|    1|
# |      59.0|   24.11|             Jul|               Jun|    1|
# |      74.2|   19.99|             Aug|               Feb|    1|
# |      77.0|   15.31|             Jul|               Jul|    1|
# |      44.0|    7.91|             Mar|               Dec|    1|
# |      77.5|   18.99|             Nov|               May|    1|
# |      51.3|   13.67|             Jan|               Mar|    1|
# +----------+--------+----------------+------------------+-----+
# only showing top 20 rows

# %%
crunched_df.printSchema()
# Out:
# root
#  |-- loan_amnt: double (nullable = true)
#  |-- term: string (nullable = true)
#  |-- int_rate: double (nullable = true)
#  |-- installment: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- emp_length: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: double (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- loan_status: string (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- dti: double (nullable = true)
#  |-- delinq_2yrs: string (nullable = true)
#  |-- earliest_cr_line: string (nullable = true)
#  |-- inq_last_6mths: string (nullable = true)
#  |-- open_acc: string (nullable = true)
#  |-- pub_rec: string (nullable = true)
#  |-- revol_bal: string (nullable = true)
#  |-- revol_util: double (nullable = true)
#  |-- total_acc: string (nullable = true)
#  |-- last_credit_pull_d: string (nullable = true)

# %% [markdown]
# ### ประกาศ Python & Spark สำหรับลด Scale ของข้อมูลด้วยเทคนิค Max-Min Normalization

# %%
from pyspark.sql.functions import *
max_annual_inc = crunched_df.select(max('annual_inc')).collect()[0][0]
min_annual_inc = crunched_df.select(min('annual_inc')).collect()[0][0]

# %%
def t_annual_inc(origin):
    return ((origin-min_annual_inc)/(max_annual_inc-min_annual_inc))

# %%
normalized_annual_inc = udf(lambda x: t_annual_inc(x),DoubleType())

# %%
max_loan_amnt = crunched_df.select(max('loan_amnt')).collect()[0][0]
min_loan_amnt = crunched_df.select(min('loan_amnt')).collect()[0][0]

# %%
def t_loan_amnt(origin):
    return ((origin-min_loan_amnt)/(max_loan_amnt-min_loan_amnt))

# %%
normalized_loan_amnt = udf(lambda x: t_loan_amnt(x),DoubleType())

# %%
normalized_df = crunched_df.withColumn('loan_amnt'\
                ,normalized_loan_amnt(crunched_df['loan_amnt'])).\
withColumn('annual_inc',normalized_annual_inc(crunched_df['annual_inc']))

# %%
normalized_df.select(['loan_amnt','annual_inc']).describe().show()
# Out:
# +-------+-------------------+--------------------+
# |summary|          loan_amnt|          annual_inc|
# +-------+-------------------+--------------------+
# |  count|            1429645|             1429645|
# |   mean| 0.3683769052044879|0.001329699400788...|
# | stddev|0.24722695810246725|0.002200369509003...|
# |    min|                0.0|                 0.0|
# |    max|                1.0|                 1.0|
# +-------+-------------------+--------------------+

# %%
normalized_df.printSchema()
# Out:
# root
#  |-- loan_amnt: double (nullable = true)
#  |-- term: string (nullable = true)
#  |-- int_rate: double (nullable = true)
#  |-- installment: string (nullable = true)
#  |-- grade: string (nullable = true)
#  |-- emp_length: string (nullable = true)
#  |-- home_ownership: string (nullable = true)
#  |-- annual_inc: double (nullable = true)
#  |-- verification_status: string (nullable = true)
#  |-- loan_status: string (nullable = true)
#  |-- purpose: string (nullable = true)
#  |-- addr_state: string (nullable = true)
#  |-- dti: double (nullable = true)
#  |-- delinq_2yrs: string (nullable = true)
#  |-- earliest_cr_line: string (nullable = true)
#  |-- inq_last_6mths: string (nullable = true)
#  |-- open_acc: string (nullable = true)
#  |-- pub_rec: string (nullable = true)
#  |-- revol_bal: string (nullable = true)
#  |-- revol_util: double (nullable = true)
#  |-- total_acc: string (nullable = true)
#  |-- last_credit_pull_d: string (nullable = true)

# %% [markdown]
# ### แสดงให้เห็นว่ามี Class อื่นๆ ที่ไม่เกี่ยวข้องกับการ Make Prediction อยู่ด้วย

# %%
normalized_df.groupBy('loan_status').count().show()
# Out:
# +------------------+------+
# |       loan_status| count|
# +------------------+------+
# |        Fully Paid|582923|
# |           Default|  1416|
# |   In Grace Period|  6125|
# |       Charged Off|152817|
# |Late (31-120 days)| 19405|
# |           Current|661982|
# | Late (16-30 days)|  4977|
# +------------------+------+

# %% [markdown]
# ### เลือกมาเฉพาะ Row ที่มี Loan Status เป็น Fully Paid และ Charged Off

# %%
from pyspark.sql.functions import col

# %%
normalized_filtered_df = normalized_df.\
filter(col('loan_status') == 'Fully Paid').\
union(normalized_df.filter(col('loan_status') == 'Charged Off'))

# %%
normalized_filtered_df.groupBy('loan_status').count().show()
# Out:
# +-----------+------+
# |loan_status| count|
# +-----------+------+
# | Fully Paid|582923|
# |Charged Off|152817|
# +-----------+------+

# %%
normalized_filtered_df.count()
# Out:
# 735740

# %%
final_df = normalized_filtered_df.dropna(how='any')

# %%
final_df.count()
# Out:
# 735740

# %%
final_df.select(['loan_amnt','int_rate'\
                 ,'dti','home_ownership','grade']).\
show()
# Out:
# +-------------------+--------+-----+--------------+-----+
# |          loan_amnt|int_rate|  dti|home_ownership|grade|
# +-------------------+--------+-----+--------------+-----+
# | 0.2564102564102564|   13.99| 5.49|          RENT|    C|
# |0.38461538461538464|   17.99|12.61|          RENT|    D|
# |0.23076923076923078|   18.99|28.38|          RENT|    D|
# |0.20512820512820512|   14.99|20.88|      MORTGAGE|    C|
# | 0.1282051282051282|   11.39|17.94|           OWN|    B|
# |0.20512820512820512|    8.24|19.07|      MORTGAGE|    B|
# |0.10256410256410256|   13.49|11.33|      MORTGAGE|    C|
# | 0.3006410256410256|   16.99| 18.8|          RENT|    D|
# |0.38461538461538464|   13.49|13.66|          RENT|    C|
# |0.39487179487179486|   15.99| 20.3|      MORTGAGE|    C|
# | 0.1282051282051282|   12.79|17.69|          RENT|    C|
# |0.28205128205128205|   11.39| 23.2|          RENT|    B|
# |0.48717948717948717|   13.49|24.54|          RENT|    C|
# | 0.1282051282051282|   11.49|25.78|          RENT|    B|
# |0.48717948717948717|   11.44| 7.63|      MORTGAGE|    B|
# |0.28205128205128205|   18.99|28.82|          RENT|    D|
# |0.23076923076923078|   21.49|23.39|          RENT|    D|
# | 0.4358974358974359|   11.49|27.91|      MORTGAGE|    B|
# |                1.0|   14.99|12.56|          RENT|    C|
# |                1.0|   12.74|15.33|      MORTGAGE|    C|
# +-------------------+--------+-----+--------------+-----+
# only showing top 20 rows

# %% [markdown]
# # 3. Data Modeling

# %%
import pyspark
from pyspark.sql import SQLContext
from pyspark.sql.types import *
from pyspark.ml.feature import OneHotEncoder, StringIndexer
from pyspark.ml.feature import VectorAssembler
from pyspark.mllib.clustering import KMeans, KMeansModel
from pyspark.ml.feature import StringIndexer, \
VectorAssembler, OneHotEncoder, VectorIndexer
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator, \
BinaryClassificationEvaluator
from pyspark.ml.classification import LogisticRegression, \
GBTClassifier, NaiveBayes, RandomForestClassifier, DecisionTreeClassifier
from pyspark.ml import Pipeline
from pyspark.ml.clustering import *

# %% [markdown]
# ## 3.1 Transformation categorical variable to numerical one.

# %%
labelIndexer = StringIndexer(inputCol='loan_status',\
                             outputCol='indexedLabel')

# %%
labelIndexer.fit(final_df).transform(final_df).\
groupBy(['loan_status','indexedLabel']).\
count().\
show()
# Out:
# +-----------+------------+------+
# |loan_status|indexedLabel| count|
# +-----------+------------+------+
# | Fully Paid|         0.0|582923|
# |Charged Off|         1.0|152817|
# +-----------+------------+------+

# %%
homeIndexer = StringIndexer(inputCol='home_ownership',\
                            outputCol='homeIndexed')
homeOneHotEncoder = OneHotEncoder(dropLast=False,\
                                  inputCol='homeIndexed',\
                                  outputCol='homeVec')

# %%
gradeIndexer = StringIndexer(inputCol='grade',\
                             outputCol='gradeIndexed')
# gradeOneHotEncoder = OneHotEncoder(dropLast=False,\
#                                    inputCol='gradeIndexed',\
#                                    outputCol='gradeVec')

# %% [markdown]
# ## 3.2 Combines selected columns into a single vector column.

# %%
featureAssembler = VectorAssembler(inputCols=['loan_amnt',\
                    'int_rate','dti','homeVec','gradeIndexed'],\
                                   outputCol='***features')

# %% [markdown]
# ## 3.3 Define an algorithm.

# %%
dt = DecisionTreeClassifier(featuresCol='***features',\
                            labelCol='indexedLabel')

# %% [markdown]
# ## 3.4 Setting up the pipeline.

# %%
pipeline_dt = Pipeline().setStages([gradeIndexer,\
                                    homeIndexer,\
                                    homeOneHotEncoder,\
                                    labelIndexer,\
                                    featureAssembler,\
                                    dt])

# %%
training_df , test_df = final_df.randomSplit([0.6,0.4])

# %%
training_df
# Out:
# DataFrame[loan_amnt: double, term: string, int_rate: double, installment: string, grade: string, emp_length: string, home_ownership: string, annual_inc: double, verification_status: string, loan_status: string, purpose: string, addr_state: string, dti: double, delinq_2yrs: string, earliest_cr_line: string, inq_last_6mths: string, open_acc: string, pub_rec: string, revol_bal: string, revol_util: double, total_acc: string, last_credit_pull_d: string]

# %% [markdown]
# ## 3.5 Launch the pipeline and get a model.

# %%
model1 = pipeline_dt.fit(training_df)

# %% [markdown]
# # 4. Evaluation of Models

# %%
result_df = model1.transform(test_df)

# %%
result_df.select('loan_status',\
                 'indexedLabel','prediction')\
.filter(result_df.loan_status == 'Fully Paid').show(20)
# Out:
# +-----------+------------+----------+
# |loan_status|indexedLabel|prediction|
# +-----------+------------+----------+
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# | Fully Paid|         0.0|       0.0|
# +-----------+------------+----------+
# only showing top 20 rows

# %%
result_df.select('loan_status','indexedLabel'\
                 ,'prediction')\
.filter(result_df.loan_status == 'Charged Off').show(20)
# Out:
# +-----------+------------+----------+
# |loan_status|indexedLabel|prediction|
# +-----------+------------+----------+
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# |Charged Off|         1.0|       0.0|
# +-----------+------------+----------+
# only showing top 20 rows

# %%
result_df.groupBy(['indexedLabel','prediction']).count().show()
# Out:
# +------------+----------+------+
# |indexedLabel|prediction| count|
# +------------+----------+------+
# |         1.0|       1.0|  1638|
# |         0.0|       1.0|  1243|
# |         1.0|       0.0| 59547|
# |         0.0|       0.0|232759|
# +------------+----------+------+

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
evaluator_RF = MulticlassClassificationEvaluator(predictionCol="prediction",\
                                              labelCol='indexedLabel', \
                                                 metricName='accuracy')
print(evaluator_RF.evaluate(result_df)*100)
# Out:
# 79.40627466656728

# %%
model1.save('/user/root/savemodel')

# %%
model1.save('gs://aekanun-22jun2022-inclass/kong_savemodel1')

# %%
model1.save('gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1')

# %%
! hdfs dfs -ls /user/root/
# Out:
# Found 3 items
# drwxr-xr-x   - root hadoop          0 2022-06-29 06:24 /user/root/.sparkStaging
# -rw-r--r--   2 root hadoop 1160243241 2022-06-29 06:25 /user/root/LoanStats_web.csv
# drwxr-xr-x   - root hadoop          0 2022-06-29 09:36 /user/root/savemodel

# %%
! ls -lh
# Out:
# total 1.1G
# -rw-r--r--   1 root root   1.1G Aug 14  2021 LoanStats_web.csv
# lrwxrwxrwx   1 root root      7 May 18 17:37 bin -> usr/bin
# drwxr-xr-x   4 root root   4.0K Jun 16 00:22 boot
# -rw-r--r--   1 root root    646 Sep 10  2019 copyright
# drwxr-xr-x  15 root root   3.0K Jun 29 06:19 dev
# drwxr-xr-x  98 root root   4.0K Jun 29 09:20 etc
# drwxrwxr-x   7 root hadoop 4.0K Jun 29 06:20 hadoop
# drwxr-xr-x   3 root root   4.0K Jun 16 00:51 home
# lrwxrwxrwx   1 root root      7 May 18 17:37 lib -> usr/lib
# lrwxrwxrwx   1 root root      9 May 18 17:37 lib32 -> usr/lib32
# lrwxrwxrwx   1 root root      9 May 18 17:37 lib64 -> usr/lib64
# lrwxrwxrwx   1 root root     10 May 18 17:37 libx32 -> usr/libx32
# drwx------   2 root root    16K May 18 17:37 lost+found
# drwxr-xr-x   2 root root   4.0K May 18 17:37 media
# drwxr-xr-x   2 root root   4.0K May 18 17:37 mnt
# drwxr-xr-x   9 root root   4.0K Jun 29 06:19 opt
# dr-xr-xr-x 163 root root      0 Jun 29 06:19 proc
# drwx------   9 root root   4.0K Jun 29 06:25 root
# drwxr-xr-x  29 root root    840 Jun 29 08:20 run
# lrwxrwxrwx   1 root root      8 May 18 17:37 sbin -> usr/sbin
# -rw-r--r--   1 root root    15K Jun 29 09:28 sparkmonitor_kernelextension.log
# drwxr-xr-x   2 root root   4.0K May 18 17:37 srv
# dr-xr-xr-x  13 root root      0 Jun 29 06:19 sys
# drwxrwxrwt  33 root root   4.0K Jun 29 09:36 tmp
# drwxr-xr-x  13 root root   4.0K Jun 29 06:21 usr
# drwxr-xr-x  12 root root   4.0K Jun 16 00:51 var

# %%
! bin/hadoop fs -get /user/root/savemodel /savemodel

# %%
! ls -lh
# Out:
# total 1.1G
# -rw-r--r--   1 root root   1.1G Aug 14  2021 LoanStats_web.csv
# lrwxrwxrwx   1 root root      7 May 18 17:37 bin -> usr/bin
# drwxr-xr-x   4 root root   4.0K Jun 16 00:22 boot
# -rw-r--r--   1 root root    646 Sep 10  2019 copyright
# drwxr-xr-x  15 root root   3.0K Jun 29 06:19 dev
# drwxr-xr-x  98 root root   4.0K Jun 29 11:06 etc
# drwxrwxr-x   7 root hadoop 4.0K Jun 29 06:20 hadoop
# drwxr-xr-x   3 root root   4.0K Jun 16 00:51 home
# lrwxrwxrwx   1 root root      7 May 18 17:37 lib -> usr/lib
# lrwxrwxrwx   1 root root      9 May 18 17:37 lib32 -> usr/lib32
# lrwxrwxrwx   1 root root      9 May 18 17:37 lib64 -> usr/lib64
# lrwxrwxrwx   1 root root     10 May 18 17:37 libx32 -> usr/libx32
# drwx------   2 root root    16K May 18 17:37 lost+found
# drwxr-xr-x   2 root root   4.0K May 18 17:37 media
# drwxr-xr-x   2 root root   4.0K May 18 17:37 mnt
# drwxr-xr-x   9 root root   4.0K Jun 29 06:19 opt
# dr-xr-xr-x 161 root root      0 Jun 29 06:19 proc
# drwx------   9 root root   4.0K Jun 29 06:25 root
# drwxr-xr-x  29 root root    860 Jun 29 10:20 run
# drwxr-xr-x   4 root root   4.0K Jun 29 09:39 savemodel
# lrwxrwxrwx   1 root root      8 May 18 17:37 sbin -> usr/sbin
# -rw-r--r--   1 root root    24K Jun 29 11:05 sparkmonitor_kernelextension.log
# drwxr-xr-x   2 root root   4.0K May 18 17:37 srv
# dr-xr-xr-x  13 root root      0 Jun 29 06:19 sys
# drwxrwxrwt  33 root root   4.0K Jun 29 10:20 tmp
# drwxr-xr-x  13 root root   4.0K Jun 29 06:21 usr
# drwxr-xr-x  12 root root   4.0K Jun 16 00:51 var

# %%
! cd /home

# %%
! ls
# Out:
# LoanStats_web.csv  hadoop  lost+found  run				 tmp
# bin		   home    media       savemodel			 usr
# boot		   lib	   mnt	       sbin				 var
# copyright	   lib32   opt	       sparkmonitor_kernelextension.log
# dev		   lib64   proc        srv
# etc		   libx32  root        sys

# %%
! gsutil -m cp -r \
  "gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1" \
  .
# Out:
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/metadata/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/0_StringIndexer_6e54c0bc8ff4/data/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/metadata/part-00000...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/0_StringIndexer_6e54c0bc8ff4/data/part-00000-866b8478-9c4b-42f0-bb38-a0047e3d53a9-c000.snappy.parquet...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/0_StringIndexer_6e54c0bc8ff4/metadata/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/0_StringIndexer_6e54c0bc8ff4/metadata/part-00000...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/1_StringIndexer_43962b1ec29e/data/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/1_StringIndexer_43962b1ec29e/data/part-00000-21040f98-289e-45c9-a7b2-a179bfc2bbcd-c000.snappy.parquet...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/1_StringIndexer_43962b1ec29e/metadata/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/2_OneHotEncoder_6f29e8f4699d/metadata/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/2_OneHotEncoder_6f29e8f4699d/metadata/part-00000...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/1_StringIndexer_43962b1ec29e/metadata/part-00000...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/3_StringIndexer_03792d8af859/data/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/3_StringIndexer_03792d8af859/data/part-00000-e545bbdc-3fb7-49a7-a982-8c8ad93e1883-c000.snappy.parquet...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/3_StringIndexer_03792d8af859/metadata/part-00000...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/3_StringIndexer_03792d8af859/metadata/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/4_VectorAssembler_be8c6e42a292/metadata/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/4_VectorAssembler_be8c6e42a292/metadata/part-00000...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/5_DecisionTreeClassifier_d988f39ffcb4/data/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/5_DecisionTreeClassifier_d988f39ffcb4/data/part-00000-e7c95eca-58d6-4906-910e-b28790679933-c000.snappy.parquet...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/5_DecisionTreeClassifier_d988f39ffcb4/data/part-00001-e7c95eca-58d6-4906-910e-b28790679933-c000.snappy.parquet...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/5_DecisionTreeClassifier_d988f39ffcb4/metadata/_SUCCESS...
# Copying gs://dataproc-staging-us-west1-65900660028-lh5mj1um/kong_savemodel1/stages/5_DecisionTreeClassifier_d988f39ffcb4/metadata/part-00000...
# / [23/42 files][ 10.5 KiB/ 10.5 KiB]  99% Done
